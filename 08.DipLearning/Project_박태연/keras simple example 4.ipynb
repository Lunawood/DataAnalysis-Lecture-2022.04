# %%
from keras import layers, models
from sklearn import preprocessing
from keras.models import Model
from keras.utils import np_utils 
from keras.callbacks import ModelCheckpoint
import tensorflow.keras as tk
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn import model_selection, metrics
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import keras
from keras import backend as K
from keras.utils import np_utils
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# c:\Users\lunaw\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\Users\lunaw\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\Users\lunaw\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\Users\lunaw\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\Users\lunaw\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\Users\lunaw\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
(X_train, y_train), (X_test, y_test) = tk.datasets.data.load_data()
scaler = preprocessing.MinMaxScaler() 

# X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
# X_scaled = X_std * (max - min) + min 
# 위와 같은 식을 통해 연속형 변수를 0~1로 변환
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21184/3702673622.py in <module>
# ----> 1 (X_train, y_train), (X_test, y_test) = tk.datasets.data.load_data()
#       2 scaler = preprocessing.MinMaxScaler()
#       3
#       4 # X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
#       5 # X_scaled = X_std * (max - min) + min
#
# AttributeError: module 'keras.api._v2.keras.datasets' has no attribute 'data'

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
Nin = 13
Nh = 5
Nout = 1

x = layers.Input(shape=(Nin,), name='input_x')
hidden = layers.Dense(Nh,activation='relu')(x)
output = layers.Dense(Nout)(hidden)

model = Model(inputs=x, outputs=output)

model.compile(loss='mse', optimizer='sgd')
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_x (InputLayer)        [(None, 13)]              0
#
#  dense (Dense)               (None, 5)                 70
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 76
# Trainable params: 76
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint=ModelCheckpoint('g:/model-{epoch:04d}.h5', verbose=1, monitor='val_loss', save_best_only=True, mode='auto')

history = model.fit(X_train, y_train, epochs=300, batch_size=100, validation_split=0.2, verbose=2, callbacks=[checkpoint])
# Out:
# Epoch 1/300
#
# Epoch 00001: val_loss improved from inf to 81.88197, saving model to g:/model-0001.h5
# 4/4 - 0s - loss: 124.3932 - val_loss: 81.8820 - 186ms/epoch - 46ms/step
# Epoch 2/300
#
# Epoch 00002: val_loss improved from 81.88197 to 75.48653, saving model to g:/model-0002.h5
# 4/4 - 0s - loss: 74.9098 - val_loss: 75.4865 - 102ms/epoch - 25ms/step
# Epoch 3/300
#
# Epoch 00003: val_loss improved from 75.48653 to 72.80666, saving model to g:/model-0003.h5
# 4/4 - 0s - loss: 64.1653 - val_loss: 72.8067 - 129ms/epoch - 32ms/step
# Epoch 4/300
#
# Epoch 00004: val_loss improved from 72.80666 to 69.39986, saving model to g:/model-0004.h5
# 4/4 - 0s - loss: 61.9116 - val_loss: 69.3999 - 45ms/epoch - 11ms/step
# Epoch 5/300
#
# Epoch 00005: val_loss improved from 69.39986 to 50.67756, saving model to g:/model-0005.h5
# 4/4 - 0s - loss: 53.2152 - val_loss: 50.6776 - 42ms/epoch - 11ms/step
# Epoch 6/300
#
# Epoch 00006: val_loss did not improve from 50.67756
# 4/4 - 0s - loss: 47.7624 - val_loss: 69.4903 - 37ms/epoch - 9ms/step
# Epoch 7/300
#
# Epoch 00007: val_loss improved from 50.67756 to 49.44494, saving model to g:/model-0007.h5
# 4/4 - 0s - loss: 54.7672 - val_loss: 49.4449 - 40ms/epoch - 10ms/step
# Epoch 8/300
#
# Epoch 00008: val_loss improved from 49.44494 to 43.66061, saving model to g:/model-0008.h5
# 4/4 - 0s - loss: 54.8275 - val_loss: 43.6606 - 39ms/epoch - 10ms/step
# Epoch 9/300
#
# Epoch 00009: val_loss did not improve from 43.66061
# 4/4 - 0s - loss: 49.6146 - val_loss: 52.2195 - 34ms/epoch - 8ms/step
# Epoch 10/300
#
# Epoch 00010: val_loss improved from 43.66061 to 41.17231, saving model to g:/model-0010.h5
# 4/4 - 0s - loss: 47.9716 - val_loss: 41.1723 - 52ms/epoch - 13ms/step
# Epoch 11/300
#
# Epoch 00011: val_loss did not improve from 41.17231
# 4/4 - 0s - loss: 41.0243 - val_loss: 49.2212 - 36ms/epoch - 9ms/step
# Epoch 12/300
#
# Epoch 00012: val_loss did not improve from 41.17231
# 4/4 - 0s - loss: 39.9853 - val_loss: 58.4714 - 41ms/epoch - 10ms/step
# Epoch 13/300
#
# Epoch 00013: val_loss did not improve from 41.17231
# 4/4 - 0s - loss: 47.7084 - val_loss: 76.4529 - 34ms/epoch - 9ms/step
# Epoch 14/300
#
# Epoch 00014: val_loss did not improve from 41.17231
# 4/4 - 0s - loss: 52.6737 - val_loss: 114.1990 - 38ms/epoch - 9ms/step
# Epoch 15/300
#
# Epoch 00015: val_loss improved from 41.17231 to 34.68642, saving model to g:/model-0015.h5
# 4/4 - 0s - loss: 59.2601 - val_loss: 34.6864 - 41ms/epoch - 10ms/step
# Epoch 16/300
#
# Epoch 00016: val_loss did not improve from 34.68642
# 4/4 - 0s - loss: 33.2986 - val_loss: 39.2264 - 36ms/epoch - 9ms/step
# Epoch 17/300
#
# Epoch 00017: val_loss improved from 34.68642 to 32.39076, saving model to g:/model-0017.h5
# 4/4 - 0s - loss: 33.3111 - val_loss: 32.3908 - 47ms/epoch - 12ms/step
# Epoch 18/300
#
# Epoch 00018: val_loss improved from 32.39076 to 31.82763, saving model to g:/model-0018.h5
# 4/4 - 0s - loss: 42.4268 - val_loss: 31.8276 - 73ms/epoch - 18ms/step
# Epoch 19/300
#
# Epoch 00019: val_loss did not improve from 31.82763
# 4/4 - 0s - loss: 37.7908 - val_loss: 119.4329 - 43ms/epoch - 11ms/step
# Epoch 20/300
#
# Epoch 00020: val_loss did not improve from 31.82763
# 4/4 - 0s - loss: 112.0738 - val_loss: 36.4895 - 39ms/epoch - 10ms/step
# Epoch 21/300
#
# Epoch 00021: val_loss did not improve from 31.82763
# 4/4 - 0s - loss: 35.3748 - val_loss: 37.5742 - 37ms/epoch - 9ms/step
# Epoch 22/300
#
# Epoch 00022: val_loss improved from 31.82763 to 31.08832, saving model to g:/model-0022.h5
# 4/4 - 0s - loss: 31.3648 - val_loss: 31.0883 - 42ms/epoch - 10ms/step
# Epoch 23/300
#
# Epoch 00023: val_loss improved from 31.08832 to 29.24512, saving model to g:/model-0023.h5
# 4/4 - 0s - loss: 31.1050 - val_loss: 29.2451 - 49ms/epoch - 12ms/step
# Epoch 24/300
#
# Epoch 00024: val_loss did not improve from 29.24512
# 4/4 - 0s - loss: 28.3163 - val_loss: 40.7600 - 38ms/epoch - 9ms/step
# Epoch 25/300
#
# Epoch 00025: val_loss did not improve from 29.24512
# 4/4 - 0s - loss: 30.0962 - val_loss: 38.5560 - 30ms/epoch - 7ms/step
# Epoch 26/300
#
# Epoch 00026: val_loss did not improve from 29.24512
# 4/4 - 0s - loss: 30.2738 - val_loss: 46.7164 - 32ms/epoch - 8ms/step
# Epoch 27/300
#
# Epoch 00027: val_loss improved from 29.24512 to 27.59365, saving model to g:/model-0027.h5
# 4/4 - 0s - loss: 33.1581 - val_loss: 27.5937 - 43ms/epoch - 11ms/step
# Epoch 28/300
#
# Epoch 00028: val_loss did not improve from 27.59365
# 4/4 - 0s - loss: 26.7740 - val_loss: 46.9953 - 29ms/epoch - 7ms/step
# Epoch 29/300
#
# Epoch 00029: val_loss did not improve from 27.59365
# 4/4 - 0s - loss: 43.1371 - val_loss: 77.4793 - 39ms/epoch - 10ms/step
# Epoch 30/300
#
# Epoch 00030: val_loss did not improve from 27.59365
# 4/4 - 0s - loss: 42.1298 - val_loss: 42.5281 - 57ms/epoch - 14ms/step
# Epoch 31/300
#
# Epoch 00031: val_loss did not improve from 27.59365
# 4/4 - 0s - loss: 39.9085 - val_loss: 41.7441 - 38ms/epoch - 9ms/step
# Epoch 32/300
#
# Epoch 00032: val_loss did not improve from 27.59365
# 4/4 - 0s - loss: 33.3690 - val_loss: 36.2472 - 48ms/epoch - 12ms/step
# Epoch 33/300
#
# Epoch 00033: val_loss improved from 27.59365 to 25.82641, saving model to g:/model-0033.h5
# 4/4 - 0s - loss: 27.2164 - val_loss: 25.8264 - 49ms/epoch - 12ms/step
# Epoch 34/300
#
# Epoch 00034: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 24.8862 - val_loss: 43.2892 - 38ms/epoch - 9ms/step
# Epoch 35/300
#
# Epoch 00035: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 32.8363 - val_loss: 42.9248 - 38ms/epoch - 9ms/step
# Epoch 36/300
#
# Epoch 00036: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 30.5836 - val_loss: 39.9122 - 36ms/epoch - 9ms/step
# Epoch 37/300
#
# Epoch 00037: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 28.6424 - val_loss: 36.5960 - 37ms/epoch - 9ms/step
# Epoch 38/300
#
# Epoch 00038: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 43.1442 - val_loss: 37.5203 - 28ms/epoch - 7ms/step
# Epoch 39/300
#
# Epoch 00039: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 48.7186 - val_loss: 26.2891 - 35ms/epoch - 9ms/step
# Epoch 40/300
#
# Epoch 00040: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 25.0923 - val_loss: 34.2369 - 27ms/epoch - 7ms/step
# Epoch 41/300
#
# Epoch 00041: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 43.9412 - val_loss: 26.4089 - 28ms/epoch - 7ms/step
# Epoch 42/300
#
# Epoch 00042: val_loss did not improve from 25.82641
# 4/4 - 0s - loss: 30.5002 - val_loss: 26.2547 - 41ms/epoch - 10ms/step
# Epoch 43/300
#
# Epoch 00043: val_loss improved from 25.82641 to 25.10577, saving model to g:/model-0043.h5
# 4/4 - 0s - loss: 28.5588 - val_loss: 25.1058 - 56ms/epoch - 14ms/step
# Epoch 44/300
#
# Epoch 00044: val_loss did not improve from 25.10577
# 4/4 - 0s - loss: 23.9314 - val_loss: 34.4143 - 42ms/epoch - 10ms/step
# Epoch 45/300
#
# Epoch 00045: val_loss improved from 25.10577 to 24.96946, saving model to g:/model-0045.h5
# 4/4 - 0s - loss: 32.1026 - val_loss: 24.9695 - 46ms/epoch - 11ms/step
# Epoch 46/300
#
# Epoch 00046: val_loss did not improve from 24.96946
# 4/4 - 0s - loss: 24.1038 - val_loss: 29.3906 - 39ms/epoch - 10ms/step
# Epoch 47/300
#
# Epoch 00047: val_loss did not improve from 24.96946
# 4/4 - 0s - loss: 28.0688 - val_loss: 25.4760 - 36ms/epoch - 9ms/step
# Epoch 48/300
#
# Epoch 00048: val_loss did not improve from 24.96946
# 4/4 - 0s - loss: 23.6381 - val_loss: 32.4584 - 31ms/epoch - 8ms/step
# Epoch 49/300
#
# Epoch 00049: val_loss did not improve from 24.96946
# 4/4 - 0s - loss: 27.7146 - val_loss: 25.5342 - 38ms/epoch - 9ms/step
# Epoch 50/300
#
# Epoch 00050: val_loss improved from 24.96946 to 23.55787, saving model to g:/model-0050.h5
# 4/4 - 0s - loss: 23.2852 - val_loss: 23.5579 - 39ms/epoch - 10ms/step
# Epoch 51/300
#
# Epoch 00051: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 25.3575 - val_loss: 35.3591 - 40ms/epoch - 10ms/step
# Epoch 52/300
#
# Epoch 00052: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 45.8450 - val_loss: 30.3275 - 28ms/epoch - 7ms/step
# Epoch 53/300
#
# Epoch 00053: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 26.5990 - val_loss: 35.9411 - 37ms/epoch - 9ms/step
# Epoch 54/300
#
# Epoch 00054: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 35.1438 - val_loss: 45.7117 - 30ms/epoch - 7ms/step
# Epoch 55/300
#
# Epoch 00055: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 52.1736 - val_loss: 41.6004 - 35ms/epoch - 9ms/step
# Epoch 56/300
#
# Epoch 00056: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 31.7507 - val_loss: 46.4181 - 29ms/epoch - 7ms/step
# Epoch 57/300
#
# Epoch 00057: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 33.5535 - val_loss: 31.6956 - 35ms/epoch - 9ms/step
# Epoch 58/300
#
# Epoch 00058: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 27.6795 - val_loss: 25.7799 - 36ms/epoch - 9ms/step
# Epoch 59/300
#
# Epoch 00059: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 27.6588 - val_loss: 24.8667 - 36ms/epoch - 9ms/step
# Epoch 60/300
#
# Epoch 00060: val_loss did not improve from 23.55787
# 4/4 - 0s - loss: 23.4682 - val_loss: 25.2917 - 28ms/epoch - 7ms/step
# Epoch 61/300
#
# Epoch 00061: val_loss improved from 23.55787 to 22.61514, saving model to g:/model-0061.h5
# 4/4 - 0s - loss: 22.9185 - val_loss: 22.6151 - 46ms/epoch - 11ms/step
# Epoch 62/300
#
# Epoch 00062: val_loss did not improve from 22.61514
# 4/4 - 0s - loss: 23.1117 - val_loss: 22.9473 - 36ms/epoch - 9ms/step
# Epoch 63/300
#
# Epoch 00063: val_loss did not improve from 22.61514
# 4/4 - 0s - loss: 25.0828 - val_loss: 25.9280 - 39ms/epoch - 10ms/step
# Epoch 64/300
#
# Epoch 00064: val_loss did not improve from 22.61514
# 4/4 - 0s - loss: 22.9100 - val_loss: 37.1140 - 31ms/epoch - 8ms/step
# Epoch 65/300
#
# Epoch 00065: val_loss did not improve from 22.61514
# 4/4 - 0s - loss: 37.1077 - val_loss: 23.6125 - 36ms/epoch - 9ms/step
# Epoch 66/300
#
# Epoch 00066: val_loss did not improve from 22.61514
# 4/4 - 0s - loss: 25.7033 - val_loss: 26.3178 - 37ms/epoch - 9ms/step
# Epoch 67/300
#
# Epoch 00067: val_loss did not improve from 22.61514
# 4/4 - 0s - loss: 26.9786 - val_loss: 24.0858 - 33ms/epoch - 8ms/step
# Epoch 68/300
#
# Epoch 00068: val_loss did not improve from 22.61514
# 4/4 - 0s - loss: 23.0727 - val_loss: 30.7594 - 47ms/epoch - 12ms/step
# Epoch 69/300
#
# Epoch 00069: val_loss did not improve from 22.61514
# 4/4 - 0s - loss: 36.2022 - val_loss: 23.0875 - 46ms/epoch - 11ms/step
# Epoch 70/300
#
# Epoch 00070: val_loss improved from 22.61514 to 22.29876, saving model to g:/model-0070.h5
# 4/4 - 0s - loss: 22.0601 - val_loss: 22.2988 - 61ms/epoch - 15ms/step
# Epoch 71/300
#
# Epoch 00071: val_loss did not improve from 22.29876
# 4/4 - 0s - loss: 24.3172 - val_loss: 38.6411 - 33ms/epoch - 8ms/step
# Epoch 72/300
#
# Epoch 00072: val_loss did not improve from 22.29876
# 4/4 - 0s - loss: 45.8149 - val_loss: 42.1648 - 33ms/epoch - 8ms/step
# Epoch 73/300
#
# Epoch 00073: val_loss did not improve from 22.29876
# 4/4 - 0s - loss: 47.0744 - val_loss: 22.7377 - 34ms/epoch - 8ms/step
# Epoch 74/300
#
# Epoch 00074: val_loss improved from 22.29876 to 22.15625, saving model to g:/model-0074.h5
# 4/4 - 0s - loss: 22.5560 - val_loss: 22.1562 - 52ms/epoch - 13ms/step
# Epoch 75/300
#
# Epoch 00075: val_loss improved from 22.15625 to 22.08777, saving model to g:/model-0075.h5
# 4/4 - 0s - loss: 22.7790 - val_loss: 22.0878 - 53ms/epoch - 13ms/step
# Epoch 76/300
#
# Epoch 00076: val_loss improved from 22.08777 to 22.01567, saving model to g:/model-0076.h5
# 4/4 - 0s - loss: 21.7598 - val_loss: 22.0157 - 49ms/epoch - 12ms/step
# Epoch 77/300
#
# Epoch 00077: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 21.6815 - val_loss: 25.1974 - 44ms/epoch - 11ms/step
# Epoch 78/300
#
# Epoch 00078: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 27.1263 - val_loss: 27.2386 - 35ms/epoch - 9ms/step
# Epoch 79/300
#
# Epoch 00079: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 26.3008 - val_loss: 23.2503 - 45ms/epoch - 11ms/step
# Epoch 80/300
#
# Epoch 00080: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 23.2310 - val_loss: 22.4586 - 39ms/epoch - 10ms/step
# Epoch 81/300
#
# Epoch 00081: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 21.7616 - val_loss: 26.8904 - 37ms/epoch - 9ms/step
# Epoch 82/300
#
# Epoch 00082: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 22.2111 - val_loss: 22.7317 - 38ms/epoch - 9ms/step
# Epoch 83/300
#
# Epoch 00083: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 22.1389 - val_loss: 30.3420 - 37ms/epoch - 9ms/step
# Epoch 84/300
#
# Epoch 00084: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 28.5368 - val_loss: 34.8649 - 37ms/epoch - 9ms/step
# Epoch 85/300
#
# Epoch 00085: val_loss did not improve from 22.01567
# 4/4 - 0s - loss: 37.7506 - val_loss: 23.3452 - 33ms/epoch - 8ms/step
# Epoch 86/300
#
# Epoch 00086: val_loss improved from 22.01567 to 21.35367, saving model to g:/model-0086.h5
# 4/4 - 0s - loss: 21.2620 - val_loss: 21.3537 - 40ms/epoch - 10ms/step
# Epoch 87/300
#
# Epoch 00087: val_loss did not improve from 21.35367
# 4/4 - 0s - loss: 21.0936 - val_loss: 21.5175 - 31ms/epoch - 8ms/step
# Epoch 88/300
#
# Epoch 00088: val_loss improved from 21.35367 to 21.11337, saving model to g:/model-0088.h5
# 4/4 - 0s - loss: 23.9753 - val_loss: 21.1134 - 42ms/epoch - 10ms/step
# Epoch 89/300
#
# Epoch 00089: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 21.0822 - val_loss: 22.6088 - 34ms/epoch - 8ms/step
# Epoch 90/300
#
# Epoch 00090: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 21.0625 - val_loss: 21.1480 - 40ms/epoch - 10ms/step
# Epoch 91/300
#
# Epoch 00091: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 21.4769 - val_loss: 21.6056 - 28ms/epoch - 7ms/step
# Epoch 92/300
#
# Epoch 00092: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 21.5044 - val_loss: 25.0993 - 33ms/epoch - 8ms/step
# Epoch 93/300
#
# Epoch 00093: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 27.4859 - val_loss: 23.0832 - 30ms/epoch - 7ms/step
# Epoch 94/300
#
# Epoch 00094: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 20.7873 - val_loss: 30.6573 - 50ms/epoch - 12ms/step
# Epoch 95/300
#
# Epoch 00095: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 26.1844 - val_loss: 21.4150 - 38ms/epoch - 9ms/step
# Epoch 96/300
#
# Epoch 00096: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 21.3166 - val_loss: 21.6802 - 107ms/epoch - 27ms/step
# Epoch 97/300
#
# Epoch 00097: val_loss did not improve from 21.11337
# 4/4 - 0s - loss: 21.5411 - val_loss: 25.2758 - 65ms/epoch - 16ms/step
# Epoch 98/300
#
# Epoch 00098: val_loss improved from 21.11337 to 20.81949, saving model to g:/model-0098.h5
# 4/4 - 0s - loss: 23.5171 - val_loss: 20.8195 - 68ms/epoch - 17ms/step
# Epoch 99/300
#
# Epoch 00099: val_loss did not improve from 20.81949
# 4/4 - 0s - loss: 20.4153 - val_loss: 23.6799 - 35ms/epoch - 9ms/step
# Epoch 100/300
#
# Epoch 00100: val_loss did not improve from 20.81949
# 4/4 - 0s - loss: 22.6820 - val_loss: 22.4349 - 31ms/epoch - 8ms/step
# Epoch 101/300
#
# Epoch 00101: val_loss did not improve from 20.81949
# 4/4 - 0s - loss: 20.8683 - val_loss: 21.5230 - 39ms/epoch - 10ms/step
# Epoch 102/300
#
# Epoch 00102: val_loss did not improve from 20.81949
# 4/4 - 0s - loss: 21.4453 - val_loss: 24.1043 - 35ms/epoch - 9ms/step
# Epoch 103/300
#
# Epoch 00103: val_loss did not improve from 20.81949
# 4/4 - 0s - loss: 21.3024 - val_loss: 22.6257 - 36ms/epoch - 9ms/step
# Epoch 104/300
#
# Epoch 00104: val_loss did not improve from 20.81949
# 4/4 - 0s - loss: 25.4900 - val_loss: 21.2601 - 28ms/epoch - 7ms/step
# Epoch 105/300
#
# Epoch 00105: val_loss did not improve from 20.81949
# 4/4 - 0s - loss: 22.2708 - val_loss: 22.5182 - 35ms/epoch - 9ms/step
# Epoch 106/300
#
# Epoch 00106: val_loss improved from 20.81949 to 20.26621, saving model to g:/model-0106.h5
# 4/4 - 0s - loss: 21.2605 - val_loss: 20.2662 - 42ms/epoch - 10ms/step
# Epoch 107/300
#
# Epoch 00107: val_loss did not improve from 20.26621
# 4/4 - 0s - loss: 20.6304 - val_loss: 20.3224 - 42ms/epoch - 10ms/step
# Epoch 108/300
#
# Epoch 00108: val_loss improved from 20.26621 to 20.03164, saving model to g:/model-0108.h5
# 4/4 - 0s - loss: 23.3329 - val_loss: 20.0316 - 39ms/epoch - 10ms/step
# Epoch 109/300
#
# Epoch 00109: val_loss did not improve from 20.03164
# 4/4 - 0s - loss: 25.9358 - val_loss: 36.8335 - 38ms/epoch - 9ms/step
# Epoch 110/300
#
# Epoch 00110: val_loss did not improve from 20.03164
# 4/4 - 0s - loss: 30.9127 - val_loss: 20.2272 - 34ms/epoch - 8ms/step
# Epoch 111/300
#
# Epoch 00111: val_loss did not improve from 20.03164
# 4/4 - 0s - loss: 20.4160 - val_loss: 26.8319 - 32ms/epoch - 8ms/step
# Epoch 112/300
#
# Epoch 00112: val_loss did not improve from 20.03164
# 4/4 - 0s - loss: 22.5611 - val_loss: 23.1135 - 29ms/epoch - 7ms/step
# Epoch 113/300
#
# Epoch 00113: val_loss did not improve from 20.03164
# 4/4 - 0s - loss: 20.0301 - val_loss: 23.4778 - 33ms/epoch - 8ms/step
# Epoch 114/300
#
# Epoch 00114: val_loss did not improve from 20.03164
# 4/4 - 0s - loss: 21.6215 - val_loss: 27.2990 - 28ms/epoch - 7ms/step
# Epoch 115/300
#
# Epoch 00115: val_loss did not improve from 20.03164
# 4/4 - 0s - loss: 23.2930 - val_loss: 20.2307 - 33ms/epoch - 8ms/step
# Epoch 116/300
#
# Epoch 00116: val_loss improved from 20.03164 to 19.82958, saving model to g:/model-0116.h5
# 4/4 - 0s - loss: 19.4393 - val_loss: 19.8296 - 75ms/epoch - 19ms/step
# Epoch 117/300
#
# Epoch 00117: val_loss did not improve from 19.82958
# 4/4 - 0s - loss: 20.9783 - val_loss: 20.0471 - 42ms/epoch - 10ms/step
# Epoch 118/300
#
# Epoch 00118: val_loss did not improve from 19.82958
# 4/4 - 0s - loss: 19.5980 - val_loss: 25.8584 - 31ms/epoch - 8ms/step
# Epoch 119/300
#
# Epoch 00119: val_loss did not improve from 19.82958
# 4/4 - 0s - loss: 20.5710 - val_loss: 22.4083 - 36ms/epoch - 9ms/step
# Epoch 120/300
#
# Epoch 00120: val_loss did not improve from 19.82958
# 4/4 - 0s - loss: 21.7150 - val_loss: 24.2452 - 28ms/epoch - 7ms/step
# Epoch 121/300
#
# Epoch 00121: val_loss did not improve from 19.82958
# 4/4 - 0s - loss: 20.2988 - val_loss: 45.3240 - 32ms/epoch - 8ms/step
# Epoch 122/300
#
# Epoch 00122: val_loss improved from 19.82958 to 19.70190, saving model to g:/model-0122.h5
# 4/4 - 0s - loss: 38.4279 - val_loss: 19.7019 - 38ms/epoch - 9ms/step
# Epoch 123/300
#
# Epoch 00123: val_loss did not improve from 19.70190
# 4/4 - 0s - loss: 19.3186 - val_loss: 19.7496 - 34ms/epoch - 8ms/step
# Epoch 124/300
#
# Epoch 00124: val_loss did not improve from 19.70190
# 4/4 - 0s - loss: 19.6448 - val_loss: 21.1127 - 33ms/epoch - 8ms/step
# Epoch 125/300
#
# Epoch 00125: val_loss did not improve from 19.70190
# 4/4 - 0s - loss: 19.8205 - val_loss: 21.6835 - 31ms/epoch - 8ms/step
# Epoch 126/300
#
# Epoch 00126: val_loss did not improve from 19.70190
# 4/4 - 0s - loss: 22.0451 - val_loss: 29.8422 - 33ms/epoch - 8ms/step
# Epoch 127/300
#
# Epoch 00127: val_loss improved from 19.70190 to 19.58333, saving model to g:/model-0127.h5
# 4/4 - 0s - loss: 22.3804 - val_loss: 19.5833 - 44ms/epoch - 11ms/step
# Epoch 128/300
#
# Epoch 00128: val_loss improved from 19.58333 to 19.53848, saving model to g:/model-0128.h5
# 4/4 - 0s - loss: 19.0257 - val_loss: 19.5385 - 44ms/epoch - 11ms/step
# Epoch 129/300
#
# Epoch 00129: val_loss did not improve from 19.53848
# 4/4 - 0s - loss: 19.5473 - val_loss: 21.0902 - 35ms/epoch - 9ms/step
# Epoch 130/300
#
# Epoch 00130: val_loss did not improve from 19.53848
# 4/4 - 0s - loss: 19.5268 - val_loss: 21.9950 - 31ms/epoch - 8ms/step
# Epoch 131/300
#
# Epoch 00131: val_loss did not improve from 19.53848
# 4/4 - 0s - loss: 19.8658 - val_loss: 19.7361 - 39ms/epoch - 10ms/step
# Epoch 132/300
#
# Epoch 00132: val_loss improved from 19.53848 to 19.36237, saving model to g:/model-0132.h5
# 4/4 - 0s - loss: 22.8927 - val_loss: 19.3624 - 49ms/epoch - 12ms/step
# Epoch 133/300
#
# Epoch 00133: val_loss did not improve from 19.36237
# 4/4 - 0s - loss: 19.7889 - val_loss: 24.5782 - 41ms/epoch - 10ms/step
# Epoch 134/300
#
# Epoch 00134: val_loss did not improve from 19.36237
# 4/4 - 0s - loss: 28.4715 - val_loss: 22.0163 - 37ms/epoch - 9ms/step
# Epoch 135/300
#
# Epoch 00135: val_loss did not improve from 19.36237
# 4/4 - 0s - loss: 23.2938 - val_loss: 26.4725 - 35ms/epoch - 9ms/step
# Epoch 136/300
#
# Epoch 00136: val_loss did not improve from 19.36237
# 4/4 - 0s - loss: 21.7461 - val_loss: 21.1647 - 35ms/epoch - 9ms/step
# Epoch 137/300
#
# Epoch 00137: val_loss improved from 19.36237 to 19.18559, saving model to g:/model-0137.h5
# 4/4 - 0s - loss: 18.7967 - val_loss: 19.1856 - 41ms/epoch - 10ms/step
# Epoch 138/300
#
# Epoch 00138: val_loss did not improve from 19.18559
# 4/4 - 0s - loss: 18.9208 - val_loss: 22.4345 - 33ms/epoch - 8ms/step
# Epoch 139/300
#
# Epoch 00139: val_loss did not improve from 19.18559
# 4/4 - 0s - loss: 20.5426 - val_loss: 32.5874 - 32ms/epoch - 8ms/step
# Epoch 140/300
#
# Epoch 00140: val_loss did not improve from 19.18559
# 4/4 - 0s - loss: 32.5622 - val_loss: 21.0557 - 35ms/epoch - 9ms/step
# Epoch 141/300
#
# Epoch 00141: val_loss did not improve from 19.18559
# 4/4 - 0s - loss: 18.8126 - val_loss: 22.7872 - 28ms/epoch - 7ms/step
# Epoch 142/300
#
# Epoch 00142: val_loss improved from 19.18559 to 19.01639, saving model to g:/model-0142.h5
# 4/4 - 0s - loss: 20.8352 - val_loss: 19.0164 - 46ms/epoch - 12ms/step
# Epoch 143/300
#
# Epoch 00143: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 18.8430 - val_loss: 20.2592 - 31ms/epoch - 8ms/step
# Epoch 144/300
#
# Epoch 00144: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 19.8538 - val_loss: 22.4851 - 32ms/epoch - 8ms/step
# Epoch 145/300
#
# Epoch 00145: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 22.2545 - val_loss: 20.1431 - 39ms/epoch - 10ms/step
# Epoch 146/300
#
# Epoch 00146: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 20.5373 - val_loss: 33.7840 - 32ms/epoch - 8ms/step
# Epoch 147/300
#
# Epoch 00147: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 23.4635 - val_loss: 19.0948 - 32ms/epoch - 8ms/step
# Epoch 148/300
#
# Epoch 00148: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 17.7492 - val_loss: 21.7287 - 32ms/epoch - 8ms/step
# Epoch 149/300
#
# Epoch 00149: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 18.7620 - val_loss: 21.5887 - 31ms/epoch - 8ms/step
# Epoch 150/300
#
# Epoch 00150: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 18.7621 - val_loss: 22.6961 - 31ms/epoch - 8ms/step
# Epoch 151/300
#
# Epoch 00151: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 20.1277 - val_loss: 20.4986 - 31ms/epoch - 8ms/step
# Epoch 152/300
#
# Epoch 00152: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 18.6089 - val_loss: 22.5545 - 33ms/epoch - 8ms/step
# Epoch 153/300
#
# Epoch 00153: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 18.5684 - val_loss: 20.4689 - 32ms/epoch - 8ms/step
# Epoch 154/300
#
# Epoch 00154: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 17.8551 - val_loss: 23.9683 - 32ms/epoch - 8ms/step
# Epoch 155/300
#
# Epoch 00155: val_loss did not improve from 19.01639
# 4/4 - 0s - loss: 26.2325 - val_loss: 23.0768 - 29ms/epoch - 7ms/step
# Epoch 156/300
#
# Epoch 00156: val_loss improved from 19.01639 to 18.87916, saving model to g:/model-0156.h5
# 4/4 - 0s - loss: 21.8328 - val_loss: 18.8792 - 49ms/epoch - 12ms/step
# Epoch 157/300
#
# Epoch 00157: val_loss did not improve from 18.87916
# 4/4 - 0s - loss: 17.1297 - val_loss: 19.6683 - 37ms/epoch - 9ms/step
# Epoch 158/300
#
# Epoch 00158: val_loss did not improve from 18.87916
# 4/4 - 0s - loss: 17.8195 - val_loss: 19.5036 - 32ms/epoch - 8ms/step
# Epoch 159/300
#
# Epoch 00159: val_loss improved from 18.87916 to 18.51611, saving model to g:/model-0159.h5
# 4/4 - 0s - loss: 18.9015 - val_loss: 18.5161 - 45ms/epoch - 11ms/step
# Epoch 160/300
#
# Epoch 00160: val_loss did not improve from 18.51611
# 4/4 - 0s - loss: 18.5795 - val_loss: 18.6776 - 31ms/epoch - 8ms/step
# Epoch 161/300
#
# Epoch 00161: val_loss did not improve from 18.51611
# 4/4 - 0s - loss: 18.2304 - val_loss: 18.9740 - 31ms/epoch - 8ms/step
# Epoch 162/300
#
# Epoch 00162: val_loss did not improve from 18.51611
# 4/4 - 0s - loss: 16.9100 - val_loss: 21.0933 - 28ms/epoch - 7ms/step
# Epoch 163/300
#
# Epoch 00163: val_loss did not improve from 18.51611
# 4/4 - 0s - loss: 18.3606 - val_loss: 19.3714 - 32ms/epoch - 8ms/step
# Epoch 164/300
#
# Epoch 00164: val_loss did not improve from 18.51611
# 4/4 - 0s - loss: 18.4249 - val_loss: 19.1570 - 27ms/epoch - 7ms/step
# Epoch 165/300
#
# Epoch 00165: val_loss did not improve from 18.51611
# 4/4 - 0s - loss: 18.5551 - val_loss: 19.0618 - 31ms/epoch - 8ms/step
# Epoch 166/300
#
# Epoch 00166: val_loss did not improve from 18.51611
# 4/4 - 0s - loss: 17.6142 - val_loss: 33.2856 - 31ms/epoch - 8ms/step
# Epoch 167/300
#
# Epoch 00167: val_loss did not improve from 18.51611
# 4/4 - 0s - loss: 24.2520 - val_loss: 21.7021 - 29ms/epoch - 7ms/step
# Epoch 168/300
#
# Epoch 00168: val_loss improved from 18.51611 to 18.36996, saving model to g:/model-0168.h5
# 4/4 - 0s - loss: 17.9065 - val_loss: 18.3700 - 41ms/epoch - 10ms/step
# Epoch 169/300
#
# Epoch 00169: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.8506 - val_loss: 19.2365 - 32ms/epoch - 8ms/step
# Epoch 170/300
#
# Epoch 00170: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.7970 - val_loss: 19.8317 - 41ms/epoch - 10ms/step
# Epoch 171/300
#
# Epoch 00171: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 18.6282 - val_loss: 27.4815 - 46ms/epoch - 11ms/step
# Epoch 172/300
#
# Epoch 00172: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 24.5108 - val_loss: 27.0502 - 36ms/epoch - 9ms/step
# Epoch 173/300
#
# Epoch 00173: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 18.7134 - val_loss: 19.5894 - 89ms/epoch - 22ms/step
# Epoch 174/300
#
# Epoch 00174: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.5235 - val_loss: 24.9694 - 50ms/epoch - 12ms/step
# Epoch 175/300
#
# Epoch 00175: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 19.0955 - val_loss: 20.4592 - 44ms/epoch - 11ms/step
# Epoch 176/300
#
# Epoch 00176: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 23.0831 - val_loss: 20.1259 - 48ms/epoch - 12ms/step
# Epoch 177/300
#
# Epoch 00177: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.4297 - val_loss: 20.3594 - 32ms/epoch - 8ms/step
# Epoch 178/300
#
# Epoch 00178: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 19.7386 - val_loss: 20.9275 - 35ms/epoch - 9ms/step
# Epoch 179/300
#
# Epoch 00179: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.3135 - val_loss: 18.7331 - 33ms/epoch - 8ms/step
# Epoch 180/300
#
# Epoch 00180: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.0785 - val_loss: 21.0723 - 31ms/epoch - 8ms/step
# Epoch 181/300
#
# Epoch 00181: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 17.2149 - val_loss: 25.3688 - 31ms/epoch - 8ms/step
# Epoch 182/300
#
# Epoch 00182: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 21.1142 - val_loss: 27.5650 - 29ms/epoch - 7ms/step
# Epoch 183/300
#
# Epoch 00183: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 21.3133 - val_loss: 19.3107 - 35ms/epoch - 9ms/step
# Epoch 184/300
#
# Epoch 00184: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.2147 - val_loss: 21.8531 - 30ms/epoch - 7ms/step
# Epoch 185/300
#
# Epoch 00185: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.6476 - val_loss: 18.7127 - 33ms/epoch - 8ms/step
# Epoch 186/300
#
# Epoch 00186: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 15.6819 - val_loss: 25.8210 - 35ms/epoch - 9ms/step
# Epoch 187/300
#
# Epoch 00187: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 20.1710 - val_loss: 18.8961 - 33ms/epoch - 8ms/step
# Epoch 188/300
#
# Epoch 00188: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 21.3829 - val_loss: 24.3796 - 29ms/epoch - 7ms/step
# Epoch 189/300
#
# Epoch 00189: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 21.0228 - val_loss: 22.2845 - 33ms/epoch - 8ms/step
# Epoch 190/300
#
# Epoch 00190: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 20.0088 - val_loss: 18.8569 - 30ms/epoch - 7ms/step
# Epoch 191/300
#
# Epoch 00191: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 15.1656 - val_loss: 23.5051 - 33ms/epoch - 8ms/step
# Epoch 192/300
#
# Epoch 00192: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.1453 - val_loss: 21.0199 - 28ms/epoch - 7ms/step
# Epoch 193/300
#
# Epoch 00193: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.9523 - val_loss: 18.6244 - 31ms/epoch - 8ms/step
# Epoch 194/300
#
# Epoch 00194: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 15.2129 - val_loss: 19.7248 - 28ms/epoch - 7ms/step
# Epoch 195/300
#
# Epoch 00195: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.1516 - val_loss: 21.5875 - 32ms/epoch - 8ms/step
# Epoch 196/300
#
# Epoch 00196: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.2010 - val_loss: 22.2011 - 31ms/epoch - 8ms/step
# Epoch 197/300
#
# Epoch 00197: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.4517 - val_loss: 21.7550 - 31ms/epoch - 8ms/step
# Epoch 198/300
#
# Epoch 00198: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 17.4352 - val_loss: 22.0628 - 30ms/epoch - 7ms/step
# Epoch 199/300
#
# Epoch 00199: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 15.6804 - val_loss: 18.9042 - 29ms/epoch - 7ms/step
# Epoch 200/300
#
# Epoch 00200: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 15.9792 - val_loss: 23.0422 - 32ms/epoch - 8ms/step
# Epoch 201/300
#
# Epoch 00201: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 17.2942 - val_loss: 19.1166 - 28ms/epoch - 7ms/step
# Epoch 202/300
#
# Epoch 00202: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 15.0285 - val_loss: 18.9599 - 33ms/epoch - 8ms/step
# Epoch 203/300
#
# Epoch 00203: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 14.7128 - val_loss: 18.3869 - 35ms/epoch - 9ms/step
# Epoch 204/300
#
# Epoch 00204: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 14.5541 - val_loss: 19.9491 - 35ms/epoch - 9ms/step
# Epoch 205/300
#
# Epoch 00205: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 16.1945 - val_loss: 21.1063 - 30ms/epoch - 7ms/step
# Epoch 206/300
#
# Epoch 00206: val_loss did not improve from 18.36996
# 4/4 - 0s - loss: 14.9609 - val_loss: 18.7594 - 28ms/epoch - 7ms/step
# Epoch 207/300
#
# Epoch 00207: val_loss improved from 18.36996 to 18.32635, saving model to g:/model-0207.h5
# 4/4 - 0s - loss: 16.1260 - val_loss: 18.3264 - 40ms/epoch - 10ms/step
# Epoch 208/300
#
# Epoch 00208: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 15.0104 - val_loss: 27.6231 - 34ms/epoch - 8ms/step
# Epoch 209/300
#
# Epoch 00209: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 25.0863 - val_loss: 27.3150 - 32ms/epoch - 8ms/step
# Epoch 210/300
#
# Epoch 00210: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 17.0537 - val_loss: 19.6480 - 32ms/epoch - 8ms/step
# Epoch 211/300
#
# Epoch 00211: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 14.2491 - val_loss: 23.6065 - 33ms/epoch - 8ms/step
# Epoch 212/300
#
# Epoch 00212: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 16.5849 - val_loss: 18.9780 - 34ms/epoch - 8ms/step
# Epoch 213/300
#
# Epoch 00213: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 14.2522 - val_loss: 19.4589 - 28ms/epoch - 7ms/step
# Epoch 214/300
#
# Epoch 00214: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 14.4707 - val_loss: 18.5574 - 34ms/epoch - 8ms/step
# Epoch 215/300
#
# Epoch 00215: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 13.9891 - val_loss: 18.6468 - 32ms/epoch - 8ms/step
# Epoch 216/300
#
# Epoch 00216: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 14.3971 - val_loss: 19.7078 - 34ms/epoch - 8ms/step
# Epoch 217/300
#
# Epoch 00217: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 14.5354 - val_loss: 22.8919 - 30ms/epoch - 7ms/step
# Epoch 218/300
#
# Epoch 00218: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 15.3642 - val_loss: 19.2372 - 28ms/epoch - 7ms/step
# Epoch 219/300
#
# Epoch 00219: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 13.8811 - val_loss: 21.7204 - 33ms/epoch - 8ms/step
# Epoch 220/300
#
# Epoch 00220: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 13.8823 - val_loss: 18.6816 - 31ms/epoch - 8ms/step
# Epoch 221/300
#
# Epoch 00221: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 15.7229 - val_loss: 24.4539 - 33ms/epoch - 8ms/step
# Epoch 222/300
#
# Epoch 00222: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 14.4645 - val_loss: 24.2860 - 32ms/epoch - 8ms/step
# Epoch 223/300
#
# Epoch 00223: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 17.9820 - val_loss: 18.9826 - 32ms/epoch - 8ms/step
# Epoch 224/300
#
# Epoch 00224: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 14.2241 - val_loss: 20.6739 - 33ms/epoch - 8ms/step
# Epoch 225/300
#
# Epoch 00225: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 18.6161 - val_loss: 18.9282 - 32ms/epoch - 8ms/step
# Epoch 226/300
#
# Epoch 00226: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 13.6944 - val_loss: 23.6546 - 32ms/epoch - 8ms/step
# Epoch 227/300
#
# Epoch 00227: val_loss did not improve from 18.32635
# 4/4 - 0s - loss: 15.6702 - val_loss: 21.2527 - 32ms/epoch - 8ms/step
# Epoch 228/300
#
# Epoch 00228: val_loss improved from 18.32635 to 18.21040, saving model to g:/model-0228.h5
# 4/4 - 0s - loss: 14.3332 - val_loss: 18.2104 - 43ms/epoch - 11ms/step
# Epoch 229/300
#
# Epoch 00229: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 14.5451 - val_loss: 18.3865 - 28ms/epoch - 7ms/step
# Epoch 230/300
#
# Epoch 00230: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.9223 - val_loss: 21.9687 - 34ms/epoch - 8ms/step
# Epoch 231/300
#
# Epoch 00231: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 15.4921 - val_loss: 20.0143 - 27ms/epoch - 7ms/step
# Epoch 232/300
#
# Epoch 00232: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 14.0376 - val_loss: 38.5261 - 32ms/epoch - 8ms/step
# Epoch 233/300
#
# Epoch 00233: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 23.4516 - val_loss: 20.1874 - 28ms/epoch - 7ms/step
# Epoch 234/300
#
# Epoch 00234: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.4967 - val_loss: 18.8621 - 33ms/epoch - 8ms/step
# Epoch 235/300
#
# Epoch 00235: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.5933 - val_loss: 62.6435 - 31ms/epoch - 8ms/step
# Epoch 236/300
#
# Epoch 00236: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 40.1971 - val_loss: 24.6481 - 30ms/epoch - 7ms/step
# Epoch 237/300
#
# Epoch 00237: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 18.1198 - val_loss: 23.8937 - 30ms/epoch - 7ms/step
# Epoch 238/300
#
# Epoch 00238: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 15.0011 - val_loss: 20.8804 - 31ms/epoch - 8ms/step
# Epoch 239/300
#
# Epoch 00239: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.8396 - val_loss: 22.5283 - 27ms/epoch - 7ms/step
# Epoch 240/300
#
# Epoch 00240: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 16.3165 - val_loss: 19.6056 - 33ms/epoch - 8ms/step
# Epoch 241/300
#
# Epoch 00241: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.8140 - val_loss: 21.6895 - 28ms/epoch - 7ms/step
# Epoch 242/300
#
# Epoch 00242: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 15.1088 - val_loss: 22.3946 - 38ms/epoch - 9ms/step
# Epoch 243/300
#
# Epoch 00243: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 15.6072 - val_loss: 18.8703 - 30ms/epoch - 7ms/step
# Epoch 244/300
#
# Epoch 00244: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.2955 - val_loss: 21.0585 - 35ms/epoch - 9ms/step
# Epoch 245/300
#
# Epoch 00245: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.9108 - val_loss: 27.3318 - 31ms/epoch - 8ms/step
# Epoch 246/300
#
# Epoch 00246: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 18.4077 - val_loss: 19.5356 - 37ms/epoch - 9ms/step
# Epoch 247/300
#
# Epoch 00247: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.8744 - val_loss: 20.5076 - 31ms/epoch - 8ms/step
# Epoch 248/300
#
# Epoch 00248: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.2742 - val_loss: 21.1372 - 31ms/epoch - 8ms/step
# Epoch 249/300
#
# Epoch 00249: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 14.4704 - val_loss: 25.7085 - 31ms/epoch - 8ms/step
# Epoch 250/300
#
# Epoch 00250: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 16.7445 - val_loss: 18.3729 - 30ms/epoch - 7ms/step
# Epoch 251/300
#
# Epoch 00251: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 15.6932 - val_loss: 27.7073 - 33ms/epoch - 8ms/step
# Epoch 252/300
#
# Epoch 00252: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 19.0998 - val_loss: 26.0583 - 29ms/epoch - 7ms/step
# Epoch 253/300
#
# Epoch 00253: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 14.9007 - val_loss: 26.1153 - 32ms/epoch - 8ms/step
# Epoch 254/300
#
# Epoch 00254: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 14.2872 - val_loss: 31.8099 - 33ms/epoch - 8ms/step
# Epoch 255/300
#
# Epoch 00255: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 16.9818 - val_loss: 19.9951 - 33ms/epoch - 8ms/step
# Epoch 256/300
#
# Epoch 00256: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.0339 - val_loss: 29.9521 - 27ms/epoch - 7ms/step
# Epoch 257/300
#
# Epoch 00257: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 15.6085 - val_loss: 25.5765 - 34ms/epoch - 8ms/step
# Epoch 258/300
#
# Epoch 00258: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.7697 - val_loss: 18.9177 - 28ms/epoch - 7ms/step
# Epoch 259/300
#
# Epoch 00259: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.8747 - val_loss: 20.5548 - 31ms/epoch - 8ms/step
# Epoch 260/300
#
# Epoch 00260: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.4942 - val_loss: 19.2298 - 28ms/epoch - 7ms/step
# Epoch 261/300
#
# Epoch 00261: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.1826 - val_loss: 23.1222 - 33ms/epoch - 8ms/step
# Epoch 262/300
#
# Epoch 00262: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 15.6438 - val_loss: 46.0489 - 30ms/epoch - 7ms/step
# Epoch 263/300
#
# Epoch 00263: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 31.1858 - val_loss: 19.9760 - 32ms/epoch - 8ms/step
# Epoch 264/300
#
# Epoch 00264: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 14.0133 - val_loss: 18.3319 - 31ms/epoch - 8ms/step
# Epoch 265/300
#
# Epoch 00265: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.3024 - val_loss: 18.5476 - 32ms/epoch - 8ms/step
# Epoch 266/300
#
# Epoch 00266: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.2427 - val_loss: 19.5581 - 30ms/epoch - 7ms/step
# Epoch 267/300
#
# Epoch 00267: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.5947 - val_loss: 18.5531 - 36ms/epoch - 9ms/step
# Epoch 268/300
#
# Epoch 00268: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.8387 - val_loss: 21.0134 - 29ms/epoch - 7ms/step
# Epoch 269/300
#
# Epoch 00269: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 15.4796 - val_loss: 38.1944 - 34ms/epoch - 8ms/step
# Epoch 270/300
#
# Epoch 00270: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 20.0741 - val_loss: 26.6774 - 27ms/epoch - 7ms/step
# Epoch 271/300
#
# Epoch 00271: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 14.7891 - val_loss: 21.4919 - 30ms/epoch - 7ms/step
# Epoch 272/300
#
# Epoch 00272: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 14.4716 - val_loss: 19.9826 - 27ms/epoch - 7ms/step
# Epoch 273/300
#
# Epoch 00273: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.9576 - val_loss: 21.3559 - 34ms/epoch - 8ms/step
# Epoch 274/300
#
# Epoch 00274: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.0683 - val_loss: 18.4696 - 31ms/epoch - 8ms/step
# Epoch 275/300
#
# Epoch 00275: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.3114 - val_loss: 21.2697 - 31ms/epoch - 8ms/step
# Epoch 276/300
#
# Epoch 00276: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.0719 - val_loss: 18.8605 - 31ms/epoch - 8ms/step
# Epoch 277/300
#
# Epoch 00277: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.3140 - val_loss: 20.6297 - 29ms/epoch - 7ms/step
# Epoch 278/300
#
# Epoch 00278: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.9242 - val_loss: 18.2767 - 33ms/epoch - 8ms/step
# Epoch 279/300
#
# Epoch 00279: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 12.3819 - val_loss: 18.7468 - 28ms/epoch - 7ms/step
# Epoch 280/300
#
# Epoch 00280: val_loss did not improve from 18.21040
# 4/4 - 0s - loss: 13.3774 - val_loss: 18.3867 - 33ms/epoch - 8ms/step
# Epoch 281/300
#
# Epoch 00281: val_loss improved from 18.21040 to 18.11348, saving model to g:/model-0281.h5
# 4/4 - 0s - loss: 12.0777 - val_loss: 18.1135 - 42ms/epoch - 10ms/step
# Epoch 282/300
#
# Epoch 00282: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 12.9794 - val_loss: 20.7627 - 38ms/epoch - 9ms/step
# Epoch 283/300
#
# Epoch 00283: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 12.7384 - val_loss: 24.2321 - 37ms/epoch - 9ms/step
# Epoch 284/300
#
# Epoch 00284: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 21.5142 - val_loss: 20.3917 - 34ms/epoch - 8ms/step
# Epoch 285/300
#
# Epoch 00285: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 13.9389 - val_loss: 23.2096 - 39ms/epoch - 10ms/step
# Epoch 286/300
#
# Epoch 00286: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 17.3680 - val_loss: 18.6435 - 30ms/epoch - 7ms/step
# Epoch 287/300
#
# Epoch 00287: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 16.5482 - val_loss: 18.8008 - 41ms/epoch - 10ms/step
# Epoch 288/300
#
# Epoch 00288: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 12.9665 - val_loss: 19.6162 - 32ms/epoch - 8ms/step
# Epoch 289/300
#
# Epoch 00289: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 18.5684 - val_loss: 30.1130 - 32ms/epoch - 8ms/step
# Epoch 290/300
#
# Epoch 00290: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 16.5372 - val_loss: 19.0914 - 36ms/epoch - 9ms/step
# Epoch 291/300
#
# Epoch 00291: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 11.8757 - val_loss: 22.6743 - 33ms/epoch - 8ms/step
# Epoch 292/300
#
# Epoch 00292: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 16.7139 - val_loss: 23.2923 - 33ms/epoch - 8ms/step
# Epoch 293/300
#
# Epoch 00293: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 13.4340 - val_loss: 18.7701 - 33ms/epoch - 8ms/step
# Epoch 294/300
#
# Epoch 00294: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 11.7232 - val_loss: 20.8571 - 28ms/epoch - 7ms/step
# Epoch 295/300
#
# Epoch 00295: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 13.2445 - val_loss: 20.7649 - 35ms/epoch - 9ms/step
# Epoch 296/300
#
# Epoch 00296: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 12.2380 - val_loss: 21.5919 - 33ms/epoch - 8ms/step
# Epoch 297/300
#
# Epoch 00297: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 12.6641 - val_loss: 24.5063 - 30ms/epoch - 7ms/step
# Epoch 298/300
#
# Epoch 00298: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 18.5675 - val_loss: 26.4192 - 36ms/epoch - 9ms/step
# Epoch 299/300
#
# Epoch 00299: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 13.3346 - val_loss: 19.4423 - 34ms/epoch - 8ms/step
# Epoch 300/300
#
# Epoch 00300: val_loss did not improve from 18.11348
# 4/4 - 0s - loss: 11.8012 - val_loss: 18.7355 - 43ms/epoch - 11ms/step

# %%
def plot_loss(history, title=None):
    # summarize history for loss
    if not isinstance(history, dict):
        history = history.history

    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    if title is not None:
        plt.title(title)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Validation'], loc=0)

plot_loss(history)
plt.show()

# %%
performace_test = model.evaluate(X_test, y_test, batch_size=100)
print('\nTest Loss -> {:.2f}'.format(performace_test))
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 19.5200
#
# Test Loss -> 19.52

# %%
loaded_model=keras.models.load_model('g:/model-0281.h5')

# %%
performace_test = loaded_model.evaluate(X_test, y_test, batch_size=100)
print('\nTest Loss -> {:.2f}'.format(performace_test))
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 19.0607
#
# Test Loss -> 19.06

# %%
predicted_y = model.predict(X_test) #예측할 때는 model.predict 
plt.plot(predicted_y)
plt.plot(y_test)
plt.ylabel('Price')
plt.xlabel('observation')
plt.legend(['Predicted', 'Actual'], loc=0)

# %%
predicted_y = loaded_model.predict(X_test) #예측할 때는 model.predict

# %%
plt.plot(predicted_y)
plt.plot(y_test)
plt.ylabel('Price')
plt.xlabel('observation')
plt.legend(['Predicted', 'Actual'], loc=0)

# %%
dt=pd.read_csv('data.csv')

# %%
#y 로 사용될 columns 추출
y1=dt['M_10']
y2=dt['F_50']

# %%
#주어진 데이터에서 y로 사용된 column 들을 제외
dt = dt.drop(['M_10', 'F_50'], 1)
# Out:
# C:\Users\nowlo\AppData\Local\Temp/ipykernel_27240/2374454876.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dt = dt.drop(['M_10', 'F_50'], 1)

# %%
# dt 전처리
...


# KERAS를 이용한 신경망 구축
...


# 딥러닝 학습 및 최적의 딥러닝 모형 저장
#model.fit(....)

# %%
# 저장한 딥러닝 모형 불러오기
#loaded_model=keras.models.load_model('your_keras_models.h5')

# %%
#테스트용 데이터셋 가지고 오기
dt_for_test=pd.read_csv('data_for_test.csv')

# %%
#예시일뿐 실제 점검시에는 다른 데이터셋을 사용합니다.
dt_for_test
# Out:
#        YM   M_10   M_20    M_30    M_40    M_50    M_60   M_70   M_80   F_10  \
# 0  201611  36087  26120   84044  173002  163487  119509  53220  13614  35264
# 1  201803  34272  23438  102833  185959  177797  146067  83445  22264  33918
# 2  201904  45414  23917   97807  188741  176622  133519  75669  23645  44352
# 3  201911  40723  31849  106284  187578  188152  144195  76607  20043  39287
# 4  201912  50731  63638  126455  183364  196290  151149  79533  22226  48656
#
#     F_20    F_30    F_40    F_50    F_60   F_70   F_80
# 0  27511  131216  127008  104372  113563  51143  12466
# 1  21254  162945  143833  121685  176024  96267  22213
# 2  22852  147165  154787  119079  152152  90765  23808
# 3  32597  145019  141362  117505  133530  72768  17321
# 4  65622  175332  158342  140293  130213  70697  20169

# %%
#y 로 사용될 columns 추출
y1=dt_for_test['M_10']
y2=dt_for_test['F_50']
#주어진 데이터에서 y로 사용된 column 들을 제외
dt_for_test = dt_for_test.drop(['M_10', 'F_50'], 1)

# dt_for_test 전처리
...
# Out:
# C:\Users\nowlo\AppData\Local\Temp/ipykernel_27240/2138724362.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dt_for_test = dt_for_test.drop(['M_10', 'F_50'], 1)
# Ellipsis

# %%
#dt_for_test 의 전처리를 통해 모형에 넣을 값을 X_for_test로 변환하고 모형에 입력.
# 모형에도 도출된 예측값을 predicted_result로 저장
#predicted_result = loaded_model.predict(x=X_for_test)

# %%
# M_10에 대한 예측값, F_50에 대한 예측값 출력하고 보고할 것.
